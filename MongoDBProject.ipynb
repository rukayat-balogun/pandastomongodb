# %%
#install the required libraries
#pip install "pymongo[srv]"

# %%
#importing library

from pymongo import MongoClient
import pandas as pd

# %%
connection_string = f"mongodb+srv://Whitegg:********@pymongo.betdsqj.mongodb.net/test"
client = MongoClient(connection_string)

# %%
client
# Out:
# MongoClient(host=['ac-6dakx5t-shard-00-01.betdsqj.mongodb.net:27017', 'ac-6dakx5t-shard-00-00.betdsqj.mongodb.net:27017', 'ac-6dakx5t-shard-00-02.betdsqj.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-1xsnb8-shard-0', tls=True)

# %%
#list of existing database


test_db = client.list_database_names()
test_db
# Out:
# ['admin', 'local']

# %%
production = client.production

# %%
test_db
# Out:
# ['admin', 'local']

# %%
def insert_document():
    collection = production.person_details
    doc = {
        'name':'Whitegg',
        'gender':'Female'
    }
    insert_item = collection.insert_one(doc)
    print(insert_item)
    
    
insert_document()

# %%
production.list_collection_names()
# Out:
# ['person_details']

# %%
df = pd.read_excel("CustomerOrders.xlsx")
df
# Out:
#      omrrts First Name  Last Name  Gender            City       Country
# 0     10001  Cornelius     Kujawa    Male           Tokyo         Japan
# 1     10002    Patrica  Courville  Female  New York Metro           USA
# 2     10003    Sanford      Xiong    Male       Sao Paulo        Brazil
# 3     10004      Allen     Burrus    Male           Seoul   South Korea
# 4     10005   Kathrine   Fritzler  Female     Mexico City        Mexico
# ..      ...        ...        ...     ...             ...           ...
# 146   10146      Bobby   Greening    Male          Dallas           USA
# 147   10147  Johnathon       Haug    Male          Boston           USA
# 148   10148       Etta     Bosque  Female  Belo Horizonte        Brazil
# 149   10149      Tomas  Coppinger    Male        Khartoum         Sudan
# 150   10150      Nanci     Bonier  Female          Riyadh  Saudi Arabia
#
# [151 rows x 6 columns]

# %%
df.head(50)
# Out:
#     omrrts First Name      Last Name  Gender              City       Country
# 0    10001  Cornelius         Kujawa    Male             Tokyo         Japan
# 1    10002    Patrica      Courville  Female    New York Metro           USA
# 2    10003    Sanford          Xiong    Male         Sao Paulo        Brazil
# 3    10004      Allen         Burrus    Male             Seoul   South Korea
# 4    10005   Kathrine       Fritzler  Female       Mexico City        Mexico
# 5    10006      Colin         Minter    Male             Osaka         Japan
# 6    10007      Velda     Kimberling  Female            Manila   Philippines
# 7    10008     Vernon           Addy    Male            Mumbai         India
# 8    10009     Blythe      Fleischer  Female             Delhi         India
# 9    10010        Tad        Hammack    Male           Jakarta     Indonesia
# 10   10011    Carlita       Schroyer  Female             Lagos       Nigeria
# ...

# %%
df.columns
# Out:
# Index(['omrrts', 'First Name', 'Last Name', 'Gender', 'City', 'Country'], dtype='object')

# %%
omrrts = []
firstNames = []
lastNames= []
gender = []
city = []
country = []

for i , j in df.iterrows():
    omrrts.append(j.omrrts)
    firstNames.append(j['First Name'])
    lastNames.append(j['Last Name'])
    gender.append(j['Gender'])
    city.append(j['City'])
    country.append(j['Country'])

# %%
database = client.customerOrder
collection = database.order_details
def create_documents():

    omrrts = []
    firstNames = []
    lastNames= []
    gender = []
    city = []
    country = []

    for i , j in df.iterrows():
        omrrts.append(j.omrrts)
        firstNames.append(j['First Name'])
        lastNames.append(j['Last Name'])
        gender.append(j['Gender'])
        city.append(j['City'])
        country.append(j['Country'])

    docs = []
        
    for omrrts, firstNames, lastNames, gender, city ,country in zip(omrrts, firstNames, lastNames, gender, city ,country):
        doc = {'omrrts':omrrts, 'First Name':firstNames, 'Last Name':lastNames, 'City':city, 'Country': country}
        #person_collection.insert_one(doc)
        docs.append(doc)
        
    collection.insert_many(docs)

# %%
create_documents()
